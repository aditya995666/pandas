# %%
import pandas as pd

# %%
df=pd.read_csv("/content/data_interpolate_function.csv")

# %%
df
# Out:
#    StudentID  attenden  activity
# 0        1.0      85.0         1
# 1        2.0      90.0         2
# 2        3.0       NaN         0
# 3        NaN      92.0         3
# 4        NaN       NaN         2
# 5        NaN      95.0         1
# 6        7.0      70.0         0
# 7        8.0       NaN         1
# 8        9.0      82.0         2
# 9       10.0      91.0         3

# %%
df.interpolate()
# fill gessing value
# Out:
#    StudentID  attenden  activity
# 0        1.0      85.0         1
# 1        2.0      90.0         2
# 2        3.0      91.0         0
# 3        4.0      92.0         3
# 4        5.0      93.5         2
# 5        6.0      95.0         1
# 6        7.0      70.0         0
# 7        8.0      76.0         1
# 8        9.0      82.0         2
# 9       10.0      91.0         3

# %%
df.interpolate(axis=1)
# collumn wise gess value
# Out:
#    StudentID  attenden  activity
# 0        1.0      85.0       1.0
# 1        2.0      90.0       2.0
# 2        3.0       1.5       0.0
# 3        NaN      92.0       3.0
# 4        NaN       NaN       2.0
# 5        NaN      95.0       1.0
# 6        7.0      70.0       0.0
# 7        8.0       4.5       1.0
# 8        9.0      82.0       2.0
# 9       10.0      91.0       3.0

# %%
df.interpolate(limit=1,axis=1)
# accordint to limit fill gess value
# Out:
#    StudentID  attenden  activity
# 0        1.0      85.0       1.0
# 1        2.0      90.0       2.0
# 2        3.0       1.5       0.0
# 3        NaN      92.0       3.0
# 4        NaN       NaN       2.0
# 5        NaN      95.0       1.0
# 6        7.0      70.0       0.0
# 7        8.0       4.5       1.0
# 8        9.0      82.0       2.0
# 9       10.0      91.0       3.0

# %%
df
# Out:
#    StudentID  attenden  activity
# 0        1.0      85.0         1
# 1        2.0      90.0         2
# 2        3.0       NaN         0
# 3        NaN      92.0         3
# 4        NaN       NaN         2
# 5        NaN      95.0         1
# 6        7.0      70.0         0
# 7        8.0       NaN         1
# 8        9.0      82.0         2
# 9       10.0      91.0         3
