# %%
import pandas as pd

# %% [markdown]
# # interpolate_method_parameter

# %%
df=pd.read_csv("/content/data_interpolate_function.csv")

df
# Out:
#    StudentID  attenden  activity
# 0        1.0      85.0         1
# 1        2.0      90.0         2
# 2        3.0       NaN         0
# 3        NaN      92.0         3
# 4        NaN       NaN         2
# 5        NaN      95.0         1
# 6        7.0      70.0         0
# 7        8.0       NaN         1
# 8        9.0      82.0         2
# 9       10.0      91.0         3

# %%
df.interpolate()
# only integers value
# Out:
#    StudentID  attenden  activity
# 0        1.0      85.0         1
# 1        2.0      90.0         2
# 2        3.0      91.0         0
# 3        4.0      92.0         3
# 4        5.0      93.5         2
# 5        6.0      95.0         1
# 6        7.0      70.0         0
# 7        8.0      76.0         1
# 8        9.0      82.0         2
# 9       10.0      91.0         3

# %%
df.interpolate(method="index")
# Out:
#    StudentID  attenden  activity
# 0        1.0      85.0         1
# 1        2.0      90.0         2
# 2        3.0      91.0         0
# 3        4.0      92.0         3
# 4        5.0      93.5         2
# 5        6.0      95.0         1
# 6        7.0      70.0         0
# 7        8.0      76.0         1
# 8        9.0      82.0         2
# 9       10.0      91.0         3

# %%
df.interpolate(method="nearest")
# Out:
#    StudentID  attenden  activity
# 0        1.0      85.0         1
# 1        2.0      90.0         2
# 2        3.0      90.0         0
# 3        3.0      92.0         3
# 4        3.0      92.0         2
# 5        7.0      95.0         1
# 6        7.0      70.0         0
# 7        8.0      70.0         1
# 8        9.0      82.0         2
# 9       10.0      91.0         3

# %%
type("attenden")
# Out:
# str

# %%
df.interpolate(method="polynomial",order=1)
# Out:
#    StudentID  attenden  activity
# 0        1.0      85.0         1
# 1        2.0      90.0         2
# 2        3.0      91.0         0
# 3        4.0      92.0         3
# 4        5.0      93.5         2
# 5        6.0      95.0         1
# 6        7.0      70.0         0
# 7        8.0      76.0         1
# 8        9.0      82.0         2
# 9       10.0      91.0         3
