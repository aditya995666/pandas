# %%
import pandas as pd

# %% [markdown]
# # melt() function

# %%
df=pd.read_excel("/content/Book1.xlsx")

# %%
df
# Out:
#      gegre  year  price  ratinng
# 0   action  2008     45     67.8
# 1   action  2009     35     56.7
# 2      not  2010     24     45.7
# 3   action  2008     24     45.6
# 4      not  2009     56     43.7
# 5      not  2010      4     45.6
# 6   action  2009     43     23.5
# 7      not  2008     56     56.7
# 8  actionn  2010     34     47.7

# %%
df.melt()
# Out:
#    variable    value
# 0     gegre   action
# 1     gegre   action
# 2     gegre      not
# 3     gegre   action
# 4     gegre      not
# 5     gegre      not
# 6     gegre   action
# 7     gegre      not
# 8     gegre  actionn
# 9      year     2008
# 10     year     2009
# 11     year     2010
# 12     year     2008
# 13     year     2009
# 14     year     2010
# 15     year     2009
# 16     year     2008
# 17     year     2010
# 18    price       45
# 19    price       35
# 20    price       24
# 21    price       24
# 22    price       56
# 23    price        4
# 24    price       43
# 25    price       56
# 26    price       34
# 27  ratinng     67.8
# 28  ratinng     56.7
# 29  ratinng     45.7
# 30  ratinng     45.6
# 31  ratinng     43.7
# 32  ratinng     45.6
# 33  ratinng     23.5
# 34  ratinng     56.7
# 35  ratinng     47.7

# %%
df.melt(id_vars="gegre")
# Out:
#       gegre variable   value
# 0    action     year  2008.0
# 1    action     year  2009.0
# 2       not     year  2010.0
# 3    action     year  2008.0
# 4       not     year  2009.0
# 5       not     year  2010.0
# 6    action     year  2009.0
# 7       not     year  2008.0
# 8   actionn     year  2010.0
# 9    action    price    45.0
# 10   action    price    35.0
# 11      not    price    24.0
# 12   action    price    24.0
# 13      not    price    56.0
# 14      not    price     4.0
# 15   action    price    43.0
# 16      not    price    56.0
# 17  actionn    price    34.0
# 18   action  ratinng    67.8
# 19   action  ratinng    56.7
# 20      not  ratinng    45.7
# 21   action  ratinng    45.6
# 22      not  ratinng    43.7
# 23      not  ratinng    45.6
# 24   action  ratinng    23.5
# 25      not  ratinng    56.7
# 26  actionn  ratinng    47.7

# %%
df.melt(id_vars="gegre",value_vars="ratinng")
# Out:
#      gegre variable  value
# 0   action  ratinng   67.8
# 1   action  ratinng   56.7
# 2      not  ratinng   45.7
# 3   action  ratinng   45.6
# 4      not  ratinng   43.7
# 5      not  ratinng   45.6
# 6   action  ratinng   23.5
# 7      not  ratinng   56.7
# 8  actionn  ratinng   47.7

# %%
df.melt(id_vars="gegre",value_vars="ratinng")
# Out:
#      gegre variable  value
# 0   action  ratinng   67.8
# 1   action  ratinng   56.7
# 2      not  ratinng   45.7
# 3   action  ratinng   45.6
# 4      not  ratinng   43.7
# 5      not  ratinng   45.6
# 6   action  ratinng   23.5
# 7      not  ratinng   56.7
# 8  actionn  ratinng   47.7
