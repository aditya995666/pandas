# %% [markdown]
# pandas parameter

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/student_performance.csv")
df
# Out:
#    StudentID      Name         Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John           Male              85                 15
# 1          2     Sarah         Female              90                 20
# 2          3      Alex           Male              78                 10
# 3          4   Michael            NaN              92                 25
# 4          5      Emma         Female              88                 18
# 5          6    Olivia         Female              95                 30
# 6          7    Daniel  not_available              70                  8
# 7          8    Sophia         Female              85                 17
# 8          9     James           Male              82                 12
# 9         10  Isabella         Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# ...

# %%
df=pd.read_csv("/content/student_performance.csv",na_values="not_available")
df
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male              85                 15
# 1          2     Sarah  Female              90                 20
# 2          3      Alex    Male              78                 10
# 3          4   Michael     NaN              92                 25
# 4          5      Emma  Female              88                 18
# 5          6    Olivia  Female              95                 30
# 6          7    Daniel     NaN              70                  8
# 7          8    Sophia  Female              85                 17
# 8          9     James    Male              82                 12
# 9         10  Isabella  Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# 1             85                          2          Medium          87
# ...

# %%
df=pd.read_csv("/content/student_performance.csv",na_values=["not_avilable","nan"])
df
# Out:
#    StudentID      Name         Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John           Male              85                 15
# 1          2     Sarah         Female              90                 20
# 2          3      Alex           Male              78                 10
# 3          4   Michael            NaN              92                 25
# 4          5      Emma         Female              88                 18
# 5          6    Olivia         Female              95                 30
# 6          7    Daniel  not_available              70                  8
# 7          8    Sophia         Female              85                 17
# 8          9     James           Male              82                 12
# 9         10  Isabella         Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# ...

# %% [markdown]
# # use of keep default value  ---- nan value consider nhi krega

# %%
df=pd.read_csv("/content/student_performance.csv",keep_default_na=False)
df
# Out:
#    StudentID      Name         Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John           Male              85                 15
# 1          2     Sarah         Female              90                 20
# 2          3      Alex           Male              78                 10
# 3          4   Michael                             92                 25
# 4          5      Emma         Female              88                 18
# 5          6    Olivia         Female              95                 30
# 6          7    Daniel  not_available              70                  8
# 7          8    Sophia         Female              85                 17
# 8          9     James           Male              82                 12
# 9         10  Isabella         Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# ...

# %%
df=pd.read_csv("/content/student_performance.csv",na_filter=False)
df
# Out:
#    StudentID      Name         Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John           Male              85                 15
# 1          2     Sarah         Female              90                 20
# 2          3      Alex           Male              78                 10
# 3          4   Michael                             92                 25
# 4          5      Emma         Female              88                 18
# 5          6    Olivia         Female              95                 30
# 6          7    Daniel  not_available              70                  8
# 7          8    Sophia         Female              85                 17
# 8          9     James           Male              82                 12
# 9         10  Isabella         Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# ...

# %%
df=pd.read_csv("/content/student_performance.csv")
df
# Out:
#    StudentID      Name         Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John           Male              85                 15
# 1          2     Sarah         Female              90                 20
# 2          3      Alex           Male              78                 10
# 3          4   Michael            NaN              92                 25
# 4          5      Emma         Female              88                 18
# 5          6    Olivia         Female              95                 30
# 6          7    Daniel  not_available              70                  8
# 7          8    Sophia         Female              85                 17
# 8          9     James           Male              82                 12
# 9         10  Isabella         Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# ...

# %%
df=pd.read_csv("/content/student_performance.csv",na_values={"Gender":"not_available"})
df
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male              85                 15
# 1          2     Sarah  Female              90                 20
# 2          3      Alex    Male              78                 10
# 3          4   Michael     NaN              92                 25
# 4          5      Emma  Female              88                 18
# 5          6    Olivia  Female              95                 30
# 6          7    Daniel     NaN              70                  8
# 7          8    Sophia  Female              85                 17
# 8          9     James    Male              82                 12
# 9         10  Isabella  Female              91                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0             78                          1            High          80
# 1             85                          2          Medium          87
# ...
