# %% [markdown]
# PARAMETER OF PANDAS AS *PD*

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/sample_data/fortune1000_2024.csv")
df
# Out:
#      Rank                       Company Ticker               Sector  \
# 0       1                       Walmart    WMT            Retailing
# 1       2                        Amazon   AMZN            Retailing
# 2       3                         Apple   AAPL           Technology
# 3       4            UnitedHealth Group    UNH          Health Care
# 4       5            Berkshire Hathaway   BRKA           Financials
# ..    ...                           ...    ...                  ...
# 995   996              Allegiant Travel   ALGT       Transportation
# 996   997                       Dropbox    DBX           Technology
# 997   998                Exact Sciences   EXAS          Health Care
# 998   999              BWX Technologies   BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.    CCO    Business Services
#
#                                      Industry Profitable Founder_is_CEO  \
# 0                       General Merchandisers        yes             no
# ...

# %%
df.head()
# Out:
#    Rank             Company Ticker       Sector  \
# 0     1             Walmart    WMT    Retailing
# 1     2              Amazon   AMZN    Retailing
# 2     3               Apple   AAPL   Technology
# 3     4  UnitedHealth Group    UNH  Health Care
# 4     5  Berkshire Hathaway   BRKA   Financials
#
#                                    Industry Profitable Founder_is_CEO  \
# 0                     General Merchandisers        yes             no
# 1           Internet Services and Retailing        yes             no
# 2               Computers, Office Equipment        yes             no
# 3   Health Care: Insurance and Managed Care        yes             no
# 4  Insurance: Property and Casualty (Stock)        yes             no
#
#   FemaleCEO Growth_in_Jobs  Change_in_Rank  ...   Assets_M  \
# 0        no             no               0  ...   252399.0
# 1        no             no               0  ...   527854.0
# 2        no             no               1  ...   352583.0
# ...

# %%
df.head(1)
# Out:
#    Rank  Company Ticker     Sector               Industry Profitable  \
# 0     1  Walmart    WMT  Retailing  General Merchandisers        yes
#
#   Founder_is_CEO FemaleCEO Growth_in_Jobs  Change_in_Rank  ...  Assets_M  \
# 0             no        no             no               0  ...  252399.0
#
#                    CEO Country HeadquartersCity HeadquartersState  \
# 0  C. Douglas McMillon    U.S.      Bentonville          Arkansas
#
#                          Website  CompanyType  \
# 0  https://www.stock.walmart.com       Public
#
#                                             Footnote  MarketCap_Updated_M  \
# 0  Figures are for fiscal year ended Jan. 31, 202...             559911.0
#
#     Updated
# 0  8/5/2024
#
# [1 rows x 32 columns]

# %%
df.tail()
# Out:
#      Rank                       Company Ticker               Sector  \
# 995   996              Allegiant Travel   ALGT       Transportation
# 996   997                       Dropbox    DBX           Technology
# 997   998                Exact Sciences   EXAS          Health Care
# 998   999              BWX Technologies   BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.    CCO    Business Services
#
#                    Industry Profitable Founder_is_CEO FemaleCEO  \
# 995                Airlines        yes             no        no
# 996       Computer Software        yes            yes        no
# 997         Pharmaceuticals         no             no        no
# 998     Aerospace & Defense        yes             no        no
# 999  Advertising, marketing         no             no        no
#
#     Growth_in_Jobs  Change_in_Rank  ... Assets_M                       CEO  \
# 995            yes               0  ...   4869.4  Maurice J. Gallagher Jr.
# ...

# %%
df.tail(2)
# Out:
#      Rank                       Company Ticker               Sector  \
# 998   999              BWX Technologies   BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.    CCO    Business Services
#
#                    Industry Profitable Founder_is_CEO FemaleCEO  \
# 998     Aerospace & Defense        yes             no        no
# 999  Advertising, marketing         no             no        no
#
#     Growth_in_Jobs  Change_in_Rank  ... Assets_M             CEO Country  \
# 998            yes               0  ...   2747.1  Rex D. Geveden    U.S.
# 999             no             -10  ...   4722.5  Scott R. Wells    U.S.
#
#     HeadquartersCity HeadquartersState                              Website  \
# 998        Lynchburg          Virginia                 https://www.bwxt.com
# 999      San Antonio             Texas  https://www.clearchanneloutdoor.com
#
#      CompanyType                                           Footnote  \
# ...

# %% [markdown]
# any_column change *datatype*

# %%
df=pd.read_csv("/content/sample_data/fortune1000_2024.csv",dtype={"Rank":float})
df
# Out:
#        Rank                       Company Ticker               Sector  \
# 0       1.0                       Walmart    WMT            Retailing
# 1       2.0                        Amazon   AMZN            Retailing
# 2       3.0                         Apple   AAPL           Technology
# 3       4.0            UnitedHealth Group    UNH          Health Care
# 4       5.0            Berkshire Hathaway   BRKA           Financials
# ..      ...                           ...    ...                  ...
# 995   996.0              Allegiant Travel   ALGT       Transportation
# 996   997.0                       Dropbox    DBX           Technology
# 997   998.0                Exact Sciences   EXAS          Health Care
# 998   999.0              BWX Technologies   BWXT  Aerospace & Defense
# 999  1000.0  Clear Channel Outdoor Hldgs.    CCO    Business Services
#
#                                      Industry Profitable Founder_is_CEO  \
# ...

# %%
df=pd.read_csv("/content/sample_data/fortune1000_2024.csv",dtype={"Rank":str})
df
# Out:
#      Rank                       Company Ticker               Sector  \
# 0       1                       Walmart    WMT            Retailing
# 1       2                        Amazon   AMZN            Retailing
# 2       3                         Apple   AAPL           Technology
# 3       4            UnitedHealth Group    UNH          Health Care
# 4       5            Berkshire Hathaway   BRKA           Financials
# ..    ...                           ...    ...                  ...
# 995   996              Allegiant Travel   ALGT       Transportation
# 996   997                       Dropbox    DBX           Technology
# 997   998                Exact Sciences   EXAS          Health Care
# 998   999              BWX Technologies   BWXT  Aerospace & Defense
# 999  1000  Clear Channel Outdoor Hldgs.    CCO    Business Services
#
#                                      Industry Profitable Founder_is_CEO  \
# 0                       General Merchandisers        yes             no
# ...

# %% [markdown]
# # true_value=[] ka use kerke ham yes value ko true value me change ker skte hai and same as false_value *italicized text*
