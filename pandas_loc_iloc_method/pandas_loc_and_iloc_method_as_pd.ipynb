# %%
import pandas as pd

# %%
df=pd.read_csv("/content/student_performance_prediction.csv")

# %%
df.head()
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
# 3     S00004                  17.6             76.8             62.4
# 4     S00005                   8.8             89.3             72.7
#
#   Participation in Extracurricular Activities Unnamed: 5 Passed
# 0                                         Yes          1    Yes
# 1                                          No          2     No
# 2                                          No          3     No
# 3                                         Yes          4     No
# 4                                          No          5     No

# %%
df.loc[0]
# Out:
# Student ID                                     S00001
# Study Hours per Week                             12.5
# Attendance Rate                                   NaN
# Previous Grades                                  75.0
# Participation in Extracurricular Activities       Yes
# Unnamed: 5                                          1
# Passed                                            Yes
# Name: 0, dtype: object

# %%
df.loc[[0,1,2,3,4]]
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
# 3     S00004                  17.6             76.8             62.4
# 4     S00005                   8.8             89.3             72.7
#
#   Participation in Extracurricular Activities Unnamed: 5 Passed
# 0                                         Yes          1    Yes
# 1                                          No          2     No
# 2                                          No          3     No
# 3                                         Yes          4     No
# 4                                          No          5     No

# %%
df.loc[3,"Student ID"]
# Out:
# 'S00004'

# %%
# slicing
df.loc[0:3,"Student ID"]
# Out:
# 0    S00001
# 1    S00002
# 2    S00003
# 3    S00004
# Name: Student ID, dtype: object

# %%
#  use of conditional operater
df.loc[df["Study Hours per Week"] < 10]
# Out:
#       Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 1         S00002                   9.3             95.3             60.6
# 4         S00005                   8.8             89.3             72.7
# 5         S00006                   8.8             73.8              NaN
# 8         S00009                   7.7            100.1             91.9
# 10        S00011                   7.7             54.1             72.3
# ...          ...                   ...              ...              ...
# 39984     S39985                   5.8             39.4             73.0
# 39985     S39986                   2.0             64.6             80.4
# 39987     S39988                   8.6             84.6             58.8
# 39993     S39994                   7.0             86.3             65.5
# 39994     S39995                   5.1             92.1             46.1
#
#       Participation in Extracurricular Activities Unnamed: 5 Passed
# ...

# %%
df.loc[df["Previous Grades"] < 23]
# Out:
#       Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 1010      S01011                  16.6             64.8             18.0
# 1503      S01504                  10.0             57.6             20.7
# 1730      S01731                   8.9            104.3             21.7
# 2939      S02940                   8.0             77.2             13.6
# 3895      S03896                  15.0             85.9             17.8
# ...          ...                   ...              ...              ...
# 39224     S39225                  13.9             39.3             18.2
# 39389     S39390                  10.8             72.3             20.5
# 39576     S39577                  16.7             92.3             20.6
# 39678     S39679                   9.3             71.3             18.8
# 39851     S39852                  10.5             47.9             22.8
#
#       Participation in Extracurricular Activities Unnamed: 5 Passed
# ...

# %% [markdown]
# # iloc method

# %%
df.iloc[0]
# Out:
# Student ID                                     S00001
# Study Hours per Week                             12.5
# Attendance Rate                                   NaN
# Previous Grades                                  75.0
# Participation in Extracurricular Activities       Yes
# Unnamed: 5                                          1
# Passed                                            Yes
# Name: 0, dtype: object

# %%
# slicing
df.iloc[:,1]
# Out:
# 0        12.5
# 1         9.3
# 2        13.2
# 3        17.6
# 4         8.8
#          ...
# 39995    15.6
# 39996    11.3
# 39997    13.1
# 39998    14.1
# 39999    11.8
# Name: Study Hours per Week, Length: 40000, dtype: float64

# %%
df.iloc[[0,1,2]]
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
#
#   Participation in Extracurricular Activities Unnamed: 5 Passed
# 0                                         Yes          1    Yes
# 1                                          No          2     No
# 2                                          No          3     No

# %%
df.iloc[:,[0,1]]
# Out:
#       Student ID  Study Hours per Week
# 0         S00001                  12.5
# 1         S00002                   9.3
# 2         S00003                  13.2
# 3         S00004                  17.6
# 4         S00005                   8.8
# ...          ...                   ...
# 39995     S39996                  15.6
# 39996     S39997                  11.3
# 39997     S39998                  13.1
# 39998     S39999                  14.1
# 39999     S40000                  11.8
#
# [40000 rows x 2 columns]

# %%
df.iloc[:,[0,1,4,6]]
# Out:
#       Student ID  Study Hours per Week  \
# 0         S00001                  12.5
# 1         S00002                   9.3
# 2         S00003                  13.2
# 3         S00004                  17.6
# 4         S00005                   8.8
# ...          ...                   ...
# 39995     S39996                  15.6
# 39996     S39997                  11.3
# 39997     S39998                  13.1
# 39998     S39999                  14.1
# 39999     S40000                  11.8
#
#       Participation in Extracurricular Activities Passed
# 0                                             Yes    Yes
# 1                                              No     No
# 2                                              No     No
# 3                                             Yes     No
# 4                                              No     No
# ...                                           ...    ...
# 39995                                         Yes     No
# ...
