# %% [markdown]
# how to create ***dataframe***

# %%
import pandas as pd

# %%
lst=[1,2,3,44,5,5]

# %%
lst
# Out:
# [1, 2, 3, 44, 5, 5]

# %%
df=pd.DataFrame(lst,index=["dffd","gg","fj","ghh","hh","gh"])
df
# Out:
#        0
# dffd   1
# gg     2
# fj     3
# ghh   44
# hh     5
# gh     5

# %%
dict={"a":1,"b":2}
dict
# Out:
# {'a': 1, 'b': 2}

# %%
df1=pd.DataFrame(dict,index=[1,2])
df1
# Out:
#    a  b
# 1  1  2
# 2  1  2

# %%
dict_of_dict={"a":2,"b":4,"c  ":3},{"a":1,"b":2}
dict_of_dict
# Out:
# ({'a': 2, 'b': 4, 'c  ': 3}, {'a': 1, 'b': 2})

# %%
df3=pd.DataFrame(dict_of_dict)

# %%
df3
# Out:
#    a  b  c
# 0  2  4  3.0
# 1  1  2  NaN

# %%
dict_of_list=[{"a":2,"f":4,"d":5},{"a":1,"b":2}]
dict_of_list
# Out:
# [{'a': 2, 'f': 4, 'd': 5}, {'a': 1, 'b': 2}]

# %%
dict_of_list
# Out:
# [{'a': 2, 'f': 4, 'd': 5}, {'a': 1, 'b': 2}]

# %%
df4=pd.DataFrame(dict_of_list)
df4
# Out:
#    a    f    d    b
# 0  2  4.0  5.0  NaN
# 1  1  NaN  NaN  2.0

# %%
list_of_list=[[1,2,3],[4,5,6]]
list_of_list
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
df5=pd.DataFrame(list_of_list)
df5
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
dict_of=[{"a":3,"v":3},{"f1":1,"f":4}]
dict_of
# Out:
# [{'a': 3, 'v': 3}, {'f1': 1, 'f': 4}]

# %%
pd.DataFrame(dict_of)
# Out:
#      a    v   f1    f
# 0  3.0  3.0  NaN  NaN
# 1  NaN  NaN  1.0  4.0

# %%
dict={"a":[2,4,5],"c":[1,2,3]}
dict
# Out:
# {'a': [2, 4, 5], 'c': [1, 2, 3]}

# %%
pd.DataFrame(dict)
# Out:
#    a  c
# 0  2  1
# 1  4  2
# 2  5  3
