# %%
import pandas as pd

# %%
df=pd.read_csv("C:\Users\DELL\OneDrive\Desktop\Python_Test\\seriel_no.csb")
# Out:
#   File "<ipython-input-2-3c3e17d13cc1>", line 1
#     df=pd.read_csv("C:\Users\DELL\OneDrive\Desktop\Python_Test\\seriel_no.csv")
#                                                                               ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
