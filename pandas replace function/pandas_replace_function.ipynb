# %%
import pandas as pd

# %% [markdown]
# # replace_function parameter

# %%
df=pd.read_csv("/content/dataset_fillna.csv")
df
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male            85.0                 15
# 1          2     Sarah  Female            90.0                 20
# 2          3      Alex    Male             NaN                 10
# 3          4   Michael     NaN            92.0                 25
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel     NaN            70.0                  8
# 7          8    Sophia  Female            85.0                 17
# 8          9     James    Male            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                          1            High          80
# 1           85.0                          2          Medium          87
# ...

# %%
df
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male            85.0                 15
# 1          2     Sarah  Female            90.0                 20
# 2          3      Alex    Male             NaN                 10
# 3          4   Michael     NaN            92.0                 25
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel     NaN            70.0                  8
# 7          8    Sophia  Female            85.0                 17
# 8          9     James    Male            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                          1            High          80
# 1           85.0                          2          Medium          87
# ...

# %%
df.replace("Male",0)
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John       0            85.0                 15
# 1          2     Sarah  Female            90.0                 20
# 2          3      Alex       0             NaN                 10
# 3          4   Michael     NaN            92.0                 25
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel     NaN            70.0                  8
# 7          8    Sophia  Female            85.0                 17
# 8          9     James       0            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                          1            High          80
# 1           85.0                          2          Medium          87
# ...

# %%
df.replace([1,2,3,4,5],"la")
# Out:
#   StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0        la      John    Male            85.0                 15
# 1        la     Sarah  Female            90.0                 20
# 2        la      Alex    Male             NaN                 10
# 3        la   Michael     NaN            92.0                 25
# 4        la      Emma  Female            88.0                 18
# 5         6    Olivia  Female            95.0                 30
# 6         7    Daniel     NaN            70.0                  8
# 7         8    Sophia  Female            85.0                 17
# 8         9     James    Male            82.0                 12
# 9        10  Isabella  Female            91.0                 22
#
#    PreviousGrade ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                        la            High          80
# 1           85.0                        la          Medium          87
# ...

# %%
df.replace({"Gender":"Male"},9)
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John       9            85.0                 15
# 1          2     Sarah  Female            90.0                 20
# 2          3      Alex       9             NaN                 10
# 3          4   Michael     NaN            92.0                 25
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel     NaN            70.0                  8
# 7          8    Sophia  Female            85.0                 17
# 8          9     James       9            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                          1            High          80
# 1           85.0                          2          Medium          87
# ...

# %%
df.replace("High",0)
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male            85.0                 15
# 1          2     Sarah  Female            90.0                 20
# 2          3      Alex    Male             NaN                 10
# 3          4   Michael     NaN            92.0                 25
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel     NaN            70.0                  8
# 7          8    Sophia  Female            85.0                 17
# 8          9     James    Male            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                          1               0          80
# 1           85.0                          2          Medium          87
# ...

# %%
df.replace("[A-Za-z]",0,regex=True)
# Out:
#    StudentID  Name  Gender  AttendanceRate  StudyHoursPerWeek  PreviousGrade  \
# 0          1     0     0.0            85.0                 15           78.0
# 1          2     0     0.0            90.0                 20           85.0
# 2          3     0     0.0             NaN                 10           65.0
# 3          4     0     NaN            92.0                 25           90.0
# 4          5     0     0.0            88.0                 18           82.0
# 5          6     0     0.0            95.0                 30            NaN
# 6          7     0     NaN            70.0                  8           60.0
# 7          8     0     0.0            85.0                 17           77.0
# 8          9     0     0.0            82.0                 12           70.0
# 9         10     0     0.0            91.0                 22           86.0
#
#    ExtracurricularActivities  ParentalSupport  FinalGrade
# 0                          1              0.0          80
# ...

# %%
df.replace({"Gender":'[A-Za-z]'},0,regex=True)
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John     0.0            85.0                 15
# 1          2     Sarah     0.0            90.0                 20
# 2          3      Alex     0.0             NaN                 10
# 3          4   Michael     NaN            92.0                 25
# 4          5      Emma     0.0            88.0                 18
# 5          6    Olivia     0.0            95.0                 30
# 6          7    Daniel     NaN            70.0                  8
# 7          8    Sophia     0.0            85.0                 17
# 8          9     James     0.0            82.0                 12
# 9         10  Isabella     0.0            91.0                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                          1            High          80
# 1           85.0                          2          Medium          87
# ...

# %%
df.replace("Male",method="ffill")
# Out:
# <ipython-input-17-875edf906ae7>:1: FutureWarning: The 'method' keyword in DataFrame.replace is deprecated and will be removed in a future version.
#   df.replace("Male",method="ffill")
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male            85.0                 15
# 1          2     Sarah  Female            90.0                 20
# 2          3      Alex  Female             NaN                 10
# 3          4   Michael     NaN            92.0                 25
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel     NaN            70.0                  8
# 7          8    Sophia  Female            85.0                 17
# 8          9     James  Female            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
# ...

# %%
df
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male            85.0                 15
# 1          2     Sarah  Female            90.0                 20
# 2          3      Alex    Male             NaN                 10
# 3          4   Michael     NaN            92.0                 25
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel     NaN            70.0                  8
# 7          8    Sophia  Female            85.0                 17
# 8          9     James    Male            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                          1            High          80
# 1           85.0                          2          Medium          87
# ...

# %%
# we are not modified of data use of inplace
df.replace(2,9,inplace=True)
df
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male            85.0                 15
# 1          9     Sarah  Female            90.0                 20
# 2          3      Alex    Male             NaN                 10
# 3          4   Michael     NaN            92.0                 25
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel     NaN            70.0                  8
# 7          8    Sophia  Female            85.0                 17
# 8          9     James    Male            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                          1            High          80
# 1           85.0                          9          Medium          87
# ...

# %%
df
# Out:
#    StudentID      Name  Gender  AttendanceRate  StudyHoursPerWeek  \
# 0          1      John    Male            85.0                 15
# 1          9     Sarah  Female            90.0                 20
# 2          3      Alex    Male             NaN                 10
# 3          4   Michael     NaN            92.0                 25
# 4          5      Emma  Female            88.0                 18
# 5          6    Olivia  Female            95.0                 30
# 6          7    Daniel     NaN            70.0                  8
# 7          8    Sophia  Female            85.0                 17
# 8          9     James    Male            82.0                 12
# 9         10  Isabella  Female            91.0                 22
#
#    PreviousGrade  ExtracurricularActivities ParentalSupport  FinalGrade
# 0           78.0                          1            High          80
# 1           85.0                          9          Medium          87
# ...
