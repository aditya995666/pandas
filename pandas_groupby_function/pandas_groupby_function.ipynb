# %%
import pandas as pd

# %%
df=pd.read_csv("/content/student_performance_prediction.csv")
df
# Out:
#       Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0         S00001                  12.5              NaN             75.0
# 1         S00002                   9.3             95.3             60.6
# 2         S00003                  13.2              NaN             64.0
# 3         S00004                  17.6             76.8             62.4
# 4         S00005                   8.8             89.3             72.7
# ...          ...                   ...              ...              ...
# 39995     S39996                  15.6             93.8             51.4
# 39996     S39997                  11.3             66.4             64.2
# 39997     S39998                  13.1             65.6             38.1
# 39998     S39999                  14.1             74.9              NaN
# 39999     S40000                  11.8             55.1             68.5
#
#       Participation in Extracurricular Activities Unnamed: 5 Passed
# ...

# %%
df1=df.fillna(0)
df1
# Out:
#       Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0         S00001                  12.5              0.0             75.0
# 1         S00002                   9.3             95.3             60.6
# 2         S00003                  13.2              0.0             64.0
# 3         S00004                  17.6             76.8             62.4
# 4         S00005                   8.8             89.3             72.7
# ...          ...                   ...              ...              ...
# 39995     S39996                  15.6             93.8             51.4
# 39996     S39997                  11.3             66.4             64.2
# 39997     S39998                  13.1             65.6             38.1
# 39998     S39999                  14.1             74.9              0.0
# 39999     S40000                  11.8             55.1             68.5
#
#       Participation in Extracurricular Activities Unnamed: 5 Passed
# ...

# %%
df1.isnull().sum()
# Out:
# Student ID                                     0
# Study Hours per Week                           0
# Attendance Rate                                0
# Previous Grades                                0
# Participation in Extracurricular Activities    0
# Unnamed: 5                                     0
# Passed                                         0
# dtype: int64

# %%
gr=df1.groupby(by="Student ID")
gr

# %%
gr.groups
# Out:
# {'S00001': [0], 'S00002': [1], 'S00003': [2], 'S00004': [3], 'S00005': [4], 'S00006': [5], 'S00007': [6], 'S00008': [7], 'S00009': [8], 'S00010': [9], 'S00011': [10], 'S00012': [11], 'S00013': [12], 'S00014': [13], 'S00015': [14], 'S00016': [15], 'S00017': [16], 'S00018': [17], 'S00019': [18], 'S00020': [19], 'S00021': [20], 'S00022': [21], 'S00023': [22], 'S00024': [23], 'S00025': [24], 'S00026': [25], 'S00027': [26], 'S00028': [27], 'S00029': [28], 'S00030': [29], 'S00031': [30], 'S00032': [31], 'S00033': [32], 'S00034': [33], 'S00035': [34], 'S00036': [35], 'S00037': [36], 'S00038': [37], 'S00039': [38], 'S00040': [39], 'S00041': [40], 'S00042': [41], 'S00043': [42], 'S00044': [43], 'S00045': [44], 'S00046': [45], 'S00047': [46], 'S00048': [47], 'S00049': [48], 'S00050': [49], 'S00051': [50], 'S00052': [51], 'S00053': [52], 'S00054': [53], 'S00055': [54], 'S00056': [55], 'S00057': [56], 'S00058': [57], 'S00059': [58], 'S00060': [59], 'S00061': [60], 'S00062': [61], 'S00063': [62],
# ...

# %%
gr1=df1.groupby(["Student ID","Study Hours per Week"]).groups
gr1
# Out:
# {('S00001', 12.5): [0], ('S00002', 9.3): [1], ('S00003', 13.2): [2], ('S00004', 17.6): [3], ('S00005', 8.8): [4], ('S00006', 8.8): [5], ('S00007', 17.9): [6], ('S00008', 13.8): [7], ('S00009', 7.7): [8], ('S00010', 12.7): [9], ('S00011', 7.7): [10], ('S00012', 7.7): [11], ('S00013', 0.0): [12], ('S00014', 0.0): [13], ('S00015', 0.0): [14], ('S00016', 7.2): [15], ('S00017', 4.9): [16], ('S00018', 11.6): [17], ('S00019', 5.5): [18], ('S00020', 2.9): [19], ('S00021', 17.3): [20], ('S00022', 8.9): [21], ('S00023', 10.3): [22], ('S00024', 2.9): [23], ('S00025', 7.3): [24], ('S00026', 10.6): [25], ('S00027', 4.2): [26], ('S00028', 11.9): [27], ('S00029', 7.0): [28], ('S00030', 8.5): [29], ('S00031', 7.0): [30], ('S00032', 19.3): [31], ('S00033', 9.9): [32], ('S00034', 4.7): [33], ('S00035', 14.1): [34], ('S00036', 3.9): [35], ('S00037', 11.0): [36], ('S00038', 0.2): [37], ('S00039', 3.4): [38], ('S00040', 11.0): [39], ('S00041', 0.0): [40], ('S00042', 10.9): [41], ('S00043', 9.4): [42], ('
# ...

# %%
for Student ,df2 in gr:
  print(Student)
  print(df2)
# Out:
# S00001
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-0ae8a72b7588> in <cell line: 1>()
#       1 for Student ,df2 in gr:
# ----> 2   print(Student).head()
#       3   print(df2).head()
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
gr1.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-6cd76915c888> in <cell line: 1>()
# ----> 1 gr1.sum()
#
# AttributeError: 'PrettyDict' object has no attribute 'sum'
